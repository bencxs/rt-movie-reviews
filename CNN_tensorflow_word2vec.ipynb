# %%
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.contrib import learn

# %%
# Load preprocessed datasets
with open('preprocess_x_1.pickle', 'rb') as handle:
    x_shuffled = pickle.load(handle)

with open('preprocess_y_1.pickle', 'rb') as handle:
    y_shuffled = pickle.load(handle)

print "Files loaded."
print "Size: {:d}".format(len(x_shuffled))
# Out:
# Files loaded.
# Size: 10662

# %%
# Split train/test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_shuffled, y_shuffled, test_size=0.1, random_state=42)

print("Train features dimensions: {:d}, {:d}".format(*X_train.shape))
print("Train labels dimensions: {:d}, {:d}".format(*y_train.shape))
print("Test features dimensions: {:d}, {:d}".format(*X_test.shape))
print("Test labels dimensions: {:d}, {:d}".format(*y_test.shape))
# Out:
# Train features dimensions: 9595, 56
# Train labels dimensions: 9595, 2
# Test features dimensions: 1067, 56
# Test labels dimensions: 1067, 2

# %%
# Build TensorFlow model
sequence_length = X_train.shape[1]
num_classes = y_train.shape[1]
vocab_size = 18758
#embedding_size = 128
embedding_size = 300
max_document_length = 56
filter_sizes = [3, 4, 5]
num_filters = 128
l2_reg_lambda = 0.0

graph = tf.Graph()
with graph.as_default():
    # Placeholders for input, output and dropout
    input_x = tf.placeholder(tf.int32, [None, sequence_length], name="input_x")
    input_y = tf.placeholder(tf.float32, [None, num_classes], name="input_y")
    dropout_keep_prob = tf.placeholder(tf.float32, name="dropout_keep_prob")

    # Keep track of L2 regularization loss
    l2_loss = tf.constant(0.0)

    # Build model
    # Embedding layer
    with tf.device('/cpu:0'), tf.name_scope("embedding"):
        W_em = tf.Variable(tf.random_uniform([vocab_size, embedding_size], -1.0, 1.0), name="W_em")
        embedded_chars = tf.nn.embedding_lookup(W_em, input_x)
        embedded_chars_expanded = tf.expand_dims(embedded_chars, -1)

    # Create a convolution + maxpool layer for each filter size
    pooled_outputs = []
    for i, filter_size in enumerate(filter_sizes):
        with tf.name_scope("conv-maxpool-%s" % filter_size):
            # Convolution layer
            filter_shape = [filter_size, embedding_size, 1, num_filters]
            W = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W-%s" % filter_size)
            b = tf.Variable(tf.constant(0.1, shape=[num_filters]), name="b-%s" % filter_size)

            conv = tf.nn.conv2d(
                embedded_chars_expanded,
                W,
                strides=[1, 1, 1, 1],
                padding="VALID",
                name="conv")

            # Apply nonlinearity
            h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")

            # Maxpooling over the outputs
            pooled = tf.nn.max_pool(
                h,
                ksize=[1, sequence_length - filter_size + 1, 1, 1],
                strides=[1, 1, 1, 1],
                padding="VALID",
                name="pool")
            pooled_outputs.append(pooled)

    # Combine all pooled features
    num_filters_total = num_filters * len(filter_sizes)
    h_pool = tf.concat(3, pooled_outputs)
    h_pool_flat = tf.reshape(h_pool, [-1, num_filters_total])

    # Add dropout
    with tf.name_scope("dropout"):
        h_drop = tf.nn.dropout(h_pool_flat, dropout_keep_prob)

    # Final (unnormalized) scores and predictions
    with tf.name_scope("output"):
        W = tf.get_variable(
            "W",
            shape=[num_filters_total, num_classes],
            initializer=tf.contrib.layers.xavier_initializer())

        b = tf.Variable(tf.constant(0.1, shape=[num_classes]), name="b")
        l2_loss += tf.nn.l2_loss(W)
        l2_loss += tf.nn.l2_loss(b)
        scores = tf.nn.xw_plus_b(h_drop, W, b, name="scores")
        predictions = tf.argmax(scores, 1, name="predictions")

    # Calculate mean cross-entropy loss
    with tf.name_scope("loss"):
        losses = tf.nn.softmax_cross_entropy_with_logits(scores, input_y)
        loss = tf.reduce_mean(losses) + l2_reg_lambda * l2_loss

    # Accuracy
    with tf.name_scope("accuracy"):
        correct_predictions = tf.equal(predictions, tf.argmax(input_y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_predictions, tf.float32), name="accuracy")

    # Optimizer
    global_step = tf.Variable(0, name="global_step", trainable=False)
    starter_learning_rate = 0.0005
    # Decay factor of 0.95 after every 10000 steps.
    with tf.name_scope('learning_rate'):
        learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 10000, 0.95)
    with tf.name_scope('optimizer'):
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss, global_step=global_step)

# %%
# ======== TensorBoard Summaries ==========
# Summaries for loss and accuracy
loss_summary = tf.scalar_summary("loss", loss)
acc_summary = tf.scalar_summary("accuracy", accuracy)

# Train Summaries
train_summary_op = tf.merge_summary([loss_summary, acc_summary, grad_summaries_merged])
train_summary_dir = os.path.join(out_dir, "summaries", "train")
train_summary_writer = tf.train.SummaryWriter(train_summary_dir, sess.graph)

# Dev summaries
dev_summary_op = tf.merge_summary([loss_summary, acc_summary])
dev_summary_dir = os.path.join(out_dir, "summaries", "dev")
dev_summary_writer = tf.train.SummaryWriter(dev_summary_dir, sess.graph)

# ======== Training =========
with tf.Session(graph=graph) as sess:
    tf.initialize_all_variables().run()
    saver = tf.train.Saver(tf.all_variables())
    print('Initialized')

    def train_step(x_batch, y_batch):   
        feed_dict = {
                input_x: x_batch,
                input_y: y_batch,
                dropout_keep_prob: 0.5
                }
        
        _, step, l, accuracy_train = sess.run(
            [optimizer, global_step, loss, accuracy], feed_dict=feed_dict)
        return step, l, accuracy_train
        
    def val_step(X_test, Y_test):
        feed_dict = {
                input_x: X_test,
                input_y: y_test,
                dropout_keep_prob: 1.0
                }
            
        step, loss_val, accuracy_val = sess.run(
            [global_step, loss, accuracy], feed_dict=feed_dict)
        return accuracy_val
 
    def load_word2vec(filepath, vocab_size, embedding_size, max_document_length):
        '''
        Loads pretrained word2vec weights to be fed into the graph,
        instead of training the word embeddings from scratch.
        '''
        # Initialize matrix
        initW = np.random.uniform(-0.25, 0.25, (vocab_size, embedding_size))
        # Load vectors from word2vec
        print("Load word2vec file {}\n".format(filepath))
        with open(filepath, 'rb') as f:
            header = f.readline()
            vocab_size, layer1_size = map(int, header.split())
            binary_len = np.dtype('float32').itemsize * layer1_size
            for line in xrange(vocab_size):
                word = []
                while True:
                    ch = f.read(1)
                    if ch == ' ':
                        word = ''.join(word)
                        break
                    if ch != '\n':
                        word.append(ch)
                vocab_processor = learn.preprocessing.VocabularyProcessor(max_document_length)
                idx = vocab_processor.vocabulary_.get(word)
                if idx != None:
                    initW[idx] = np.fromstring(f.read(binary_len), dtype='float32')
                else:
                    f.read(binary_len)
                
        sess.run(W_em.assign(initW))           
    
    def batch_iter(data, batch_size, num_epochs, shuffle=False):
        '''
        Generates a batch iterator for a dataset.
        '''
        data = np.array(data)
        data_size = len(data)
        num_batches_per_epoch = int((len(data)-1)/batch_size) + 1
        for epoch in range(num_epochs):
            # Shuffle the data at each epoch
            if shuffle:
                shuffle_indices = np.random.permutation(np.arange(data_size))
                shuffled_data = data[shuffle_indices]
            else:
                shuffled_data = data
            for batch_num in range(num_batches_per_epoch):
                start_index = batch_num * batch_size
                end_index = min((batch_num + 1) * batch_size, data_size)
                yield shuffled_data[start_index:end_index]

    batch_size = 64
    num_epochs = 20
    evaluate_every = 100
    checkpoint_every = 100
    checkpoint= '/home/ubuntu/pynb/rt-movie-reviews/cp'
    filepath = '/home/ubuntu/pynb/rt-movie-reviews/GoogleNews-vectors-negative300.bin'

    # Load word2vec weights
    load_word2vec(filepath, vocab_size, embedding_size, 56)
    # Generate batches
    batches = batch_iter(
        list(zip(X_train, y_train)), batch_size, num_epochs)
    # Training loop. For each batch...
    for batch in batches:
        x_batch, y_batch = zip(*batch)
        step, l, accuracy_train = train_step(x_batch, y_batch)
        if (step % evaluate_every == 0):
            accuracy_val = val_step(X_test, y_test)
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: {:.4f}'.format(accuracy_train))
            print('Validation accuracy: {:.4f}'.format(accuracy_val))
        if (step % checkpoint_every == 0):
            path = saver.save(sess, checkpoint, global_step=step)
            print("Saved model checkpoint to {}\n".format(path))
# Out:
# Initialized
# Load word2vec file /home/ubuntu/pynb/rt-movie-reviews/GoogleNews-vectors-negative300.bin
#
# Minibatch loss at step 100: 0.976893
# Minibatch accuracy: 0.5625
# Validation accuracy: 0.6017
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-100
#
# Minibatch loss at step 200: 0.632640
# Minibatch accuracy: 0.7031
# Validation accuracy: 0.6476
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-200
#
# Minibatch loss at step 300: 0.467359
# Minibatch accuracy: 0.7458
# Validation accuracy: 0.6617
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-300
#
# Minibatch loss at step 400: 0.487238
# Minibatch accuracy: 0.7188
# Validation accuracy: 0.7010
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-400
#
# Minibatch loss at step 500: 0.390615
# Minibatch accuracy: 0.8594
# Validation accuracy: 0.6992
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-500
#
# Minibatch loss at step 600: 0.411593
# Minibatch accuracy: 0.8475
# Validation accuracy: 0.7357
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-600
#
# Minibatch loss at step 700: 0.268751
# Minibatch accuracy: 0.9219
# Validation accuracy: 0.7470
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-700
#
# Minibatch loss at step 800: 0.160808
# Minibatch accuracy: 0.9531
# Validation accuracy: 0.7545
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-800
#
# Minibatch loss at step 900: 0.114861
# Minibatch accuracy: 0.9831
# Validation accuracy: 0.7545
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-900
#
# Minibatch loss at step 1000: 0.194233
# Minibatch accuracy: 0.9375
# Validation accuracy: 0.7563
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1000
#
# Minibatch loss at step 1100: 0.057625
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7694
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1100
#
# Minibatch loss at step 1200: 0.080914
# Minibatch accuracy: 0.9831
# Validation accuracy: 0.7769
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1200
#
# Minibatch loss at step 1300: 0.080299
# Minibatch accuracy: 0.9531
# Validation accuracy: 0.7685
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1300
#
# Minibatch loss at step 1400: 0.023993
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7657
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1400
#
# Minibatch loss at step 1500: 0.127319
# Minibatch accuracy: 0.9661
# Validation accuracy: 0.7694
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1500
#
# Minibatch loss at step 1600: 0.033984
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7619
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1600
#
# Minibatch loss at step 1700: 0.030984
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7657
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1700
#
# Minibatch loss at step 1800: 0.013606
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7657
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1800
#
# Minibatch loss at step 1900: 0.012046
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7648
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-1900
#
# Minibatch loss at step 2000: 0.009432
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7648
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2000
#
# Minibatch loss at step 2100: 0.009360
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7685
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2100
#
# Minibatch loss at step 2200: 0.007383
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7676
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2200
#
# Minibatch loss at step 2300: 0.021098
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7676
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2300
#
# Minibatch loss at step 2400: 0.005167
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7638
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2400
#
# Minibatch loss at step 2500: 0.028463
# Minibatch accuracy: 0.9844
# Validation accuracy: 0.7610
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2500
#
# Minibatch loss at step 2600: 0.005509
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7638
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2600
#
# Minibatch loss at step 2700: 0.004216
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7610
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2700
#
# Minibatch loss at step 2800: 0.026830
# Minibatch accuracy: 0.9844
# Validation accuracy: 0.7619
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2800
#
# Minibatch loss at step 2900: 0.001436
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7591
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-2900
#
# Minibatch loss at step 3000: 0.003640
# Minibatch accuracy: 1.0000
# Validation accuracy: 0.7601
# Saved model checkpoint to /home/ubuntu/pynb/rt-movie-reviews/cp-3000
